# %%
import numpy as np
from lib.plot import plot_polygon_samples, plot_polyhedron_sample, plot_polyhedron
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull
from matplotlib.patches import Polygon

# %% [markdown]
# # Samples

# %%
verts = np.load("../data/coetzer_verts_2d.npy")
samples = np.load("../data/coetzer_2d_samples.npy")
plot_polygon_samples(verts, samples, "Reparameterized Polytope With Samples", "../data/plots/coetzer_reparam_samples_3d.png")

# %%
verts = np.load("../data/coetzer_verts_3d.npy")
samples = np.load("../data/coetzer_3d_samples.npy")
plot_polyhedron_sample(verts, samples, "Reparameterized Polytope With Samples", "../data/plots/coetzer_reparam_samples_3d.png", azim=205, elev=15)

# %% [markdown]
# # Optimizers

# %%
samples = np.load("../data/coetzer_2d_12.npy")
verts = np.load("../data/coetzer_verts_2d.npy")
plot_polygon_samples(verts, samples, "Reparameterized Polytope With Optimizer for N=12", "../data/plots/coetzer_reparam_2d_12_2_best.png")

# %%
verts = np.load("../data/coetzer_verts_3d.npy")
samples = np.load("../data/coetzer_3d_12.npy")
plot_polyhedron_sample(verts, samples, "Reparameterized Polytope With Samples", "../data/plots/coetzer_reparam_3d_12_best.png", azim=205, elev=15)

# %%
verts = np.load("../data/coetzer_verts_3d.npy")
samples = np.load("../data/coetzer_3d_samples.npy")
plot_polyhedron_sample(verts, samples, "Reparameterized Polytope With Samples", "../data/plots/coetzer_reparam_samples_3d.png", azim=205, elev=15)
