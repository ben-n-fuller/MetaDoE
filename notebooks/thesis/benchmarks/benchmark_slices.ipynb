# %% [markdown]
# # Overview
# This notebook plots 2D slices of the four chosen benchmark objective functions: Griewank, Ackley, Rastrigin, and Rosenbrock.

# %%
import numpy as np
from metadoe.objectives import griewank, ackley, rastrigin, rosenbrock, plot_objective

# %%
plot_objective(griewank, "Griewank", "plots", font_size=20)

# %%
plot_objective(ackley, "Ackley", "plots", font_size=20)

# %%
plot_objective(rastrigin, "Rastrigin", "plots", font_size=20)

# %%
plot_objective(rosenbrock, "Rosenbrock", "plots", font_size=20)
