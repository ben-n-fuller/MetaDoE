# %% [markdown]
# # Overview
# This notebook plots 2D slices of the four chosen benchmark objective functions: Griewank, Ackley, Rastrigin, and Rosenbrock.

# %%
import numpy as np
from metadoe.visualization.objectives import griewank, ackley, rastrigin, rosenbrock, plot_objective

# %%
plot_objective(griewank, "Griewank", "plots")

# %%
plot_objective(ackley, "Ackley", "plots")

# %%
plot_objective(rastrigin, "Rastrigin", "plots")

# %%
plot_objective(rosenbrock, "Rosenbrock", "plots")
